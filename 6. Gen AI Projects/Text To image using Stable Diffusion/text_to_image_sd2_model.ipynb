# %%
# ------------------------------
# 1. GPU CHECK
# ------------------------------
# !nvidia-smi
# Out:
# Mon Dec  8 12:03:37 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# ------------------------------
# 4. Upload your starter_code.zip
# ------------------------------
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-04dbcffe-2ce3-4eca-a9b5-95fc4e4d51bb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-04dbcffe-2ce3-4eca-a9b5-95fc4e4d51bb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# ------------------------------
# 5. Unzip starter_code.zip
# ------------------------------
# !unzip -o starter_code.zip -d /content/
# !ls /content/starter_code
# Out:
# Archive:  starter_code.zip
#    creating: /content/starter_code/__pycache__/
#   inflating: /content/starter_code/__pycache__/trainer.cpython-312.pyc
#    creating: /content/starter_code/configs/
#   inflating: /content/starter_code/configs/artists_with_preservation.yaml
#   inflating: /content/starter_code/configs/artists_without_preservation.yaml
#   inflating: /content/starter_code/configs/pokemon_with_preservation.yaml
#   inflating: /content/starter_code/configs/pokemon_without_preservation.yaml
#    creating: /content/starter_code/data/
#  extracting: /content/starter_code/data/__init__.py
#    creating: /content/starter_code/data/__pycache__/
#   inflating: /content/starter_code/data/__pycache__/__init__.cpython-312.pyc
#   inflating: /content/starter_code/data/__pycache__/artist_dataset.cpython-312.pyc
#   inflating: /content/starter_code/data/__pycache__/dreambooth.cpython-312.pyc
#   inflating: /content/starter_code/data/__pycache__/pokemon_dataset.cpython-312.pyc
# ...

# %%
# !pip install yacs accelerate transformers datasets diffusers safetensors wandb pyyaml huggingface_hub bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 18.3 MB/s eta 0:00:00
# ...

# %%
import os
os.chdir("/content/starter_code")

# fix permissions for scripts
# !chmod +x scripts/*.sh

# %%
# %cd /content/starter_code
import sys
sys.path.append('/content/starter_code')
# Out:
# /content

# %%
# !python main.py --config configs/artists_with_preservation.yaml
# Out:
# 2025-12-08 12:33:03.912741: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765197183.933638    8314 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765197183.939830    8314 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765197183.955822    8314 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import glob
glob.glob("datasets/artists/priors/claude-monet/*")
# Out:
# ['datasets/artists/priors/claude-monet/02.jpg',
#  'datasets/artists/priors/claude-monet/04.jpg',
#  'datasets/artists/priors/claude-monet/01.jpg',
#  'datasets/artists/priors/claude-monet/00.jpg',
#  'datasets/artists/priors/claude-monet/03.jpg']
